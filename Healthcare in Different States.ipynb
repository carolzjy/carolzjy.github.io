# %% [markdown]
# The purpose is to investigate the way hospitals in different states across the United States charge their patients for chest pains.

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
healthcare=pd.read_csv("C:/Users/carol/Desktop/healthcare.csv")
print(df.head())
# Out:
#                              DRG Definition  Provider Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
#
#                       Provider Name     Provider Street Address Provider City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider State  Provider Zip Code Hospital Referral Region Description  \
# 0             AL              36301                          AL - Dothan
# ...

# %% [markdown]
# The data comes from United State Health and Human Services Department, including information like provider name, address, ID, DRG procedural, average coverage charges, and payments.

# %%
chest_pain= healthcare[healthcare['DRG Definition'] == '313 - CHEST PAIN']
california_chest_pain=chest_pain[chest_pain['Provider State'] == "CA"]
costs= california_chest_pain[' Average Covered Charges '].values
print(costs)
# Out:
# [37588.84 28014.   27270.76 38306.   18430.75 36153.7  39190.61 20738.6
#  14502.68 29420.48 15769.23 18574.02 24943.71 23206.66 27594.96 13159.5
#  27401.45 24593.24 44102.25 17097.11 15021.8  20898.24 27182.25 22252.66
#  31580.41 21144.33 29354.29 29332.07 37053.76 30570.08 38929.08 30090.33
#  25129.5  18450.18 28167.72 36706.66 29109.3  35647.58 29103.77 29680.68
#  26529.41 24998.34 19559.08 24889.04 23402.14 38300.71 52980.65 13809.74
#  44557.07 19131.12 66827.55 21850.11 21343.11 27887.02 37953.91 22615.92
#  17135.92 32270.96 20409.25 44902.7  25620.07 20432.03 32366.84 31588.
#  37190.6  39413.72 34763.22 62419.81 28968.47 12655.5  43344.14 56381.88
#  21292.97 28608.42 13489.08 35221.42 18669.83 48067.05 32735.27 22397.
#  33320.76 40468.97 26889.61 43516.14 30394.86 24327.88 37007.21 33289.06
#  42641.2  15729.06 35858.21 49313.57 11232.27 14500.58 27217.28 20589.84
#  15988.25 34973.05 50707.39 18409.7  24885.64 53408.46 19616.21 20146.6
# ...

# %%
plt.figure(figsize=(20,6))
plt.boxplot(costs)
plt.show()

# %% [markdown]
# The boxplot shows the average costs for chest pain surgeries in California.Most of them cost between $1000 and $6000, with a median of close to $3000.

# %%
states=chest_pain['Provider State'].unique()

datasets= []
for i in states: 
  datasets.append(chest_pain[chest_pain['Provider State'] == i][' Average Covered Charges '].values)
# Out:
# [array([ 6760.53,  7263.36, 10160.13,  9814.26,  8508.57,  9237.1 ,
#         7252.33,  8069.5 , 13453.9 ,  6461.63,  8949.04,  8405.25,
#         8529.85,  7802.01,  6674.73,  7741.93,  8143.51, 15834.12,
#         6982.15,  6306.77, 10944.32, 10062.22,  5614.52,  8582.21,
#         6243.87, 10737.81,  8846.54,  6835.98, 20504.91,  6732.65,
#         9519.28,  9277.05,  8860.04,  6994.6 , 10135.25,  9975.71,
#         8569.26,  7055.11,  8875.3 , 11304.66, 10347.58,  4820.37,
#        22368.11,  5640.84,  8774.95, 11465.08,  6713.43, 13827.62,
#         8864.9 ,  8872.12,  7493.07,  7589.08]), array([19540.55, 20241.84,  6417.2 , 13311.78, 21375.25, 12569.92,
#        12072.04,  9999.98,  7274.72,  6660.36, 15449.91,  9091.22,
#        20074.9 , 21093.72, 39035.25, 23769.85,  4868.25, 18100.56,
#         4308.61, 23505.03, 17560.85, 10957.75,  6935.45,  7216.7 ,
#        14627.35,  7006.38, 24424.71,  8700.78, 12268.8 , 15938.66,
# ...

# %%
plt.figure(figsize=(20,6))
plt.boxplot(datasets, labels=states)
plt.show()

# %% [markdown]
# Now looking at boxplots for all states.
#
# California has the largest spread and outliers, meaning the costs of chest pain procedures vary the most in California.
#
# Meanwhile, New Jersey has the largest median, so the procedures are generally more expensive in New Jersey than in other states. Massachusetts and Maryland are the cheapest.
